# %%
# !provengo --batch-mode create SheepWolfCabbage
# Out:
#         / /
#      /\/ /   ____
#   /\/ /\/ / |  _ \ _ __  _____   __ ___  _ __   __ _  ___
#  /  \/\/\/  | |_) | '__|/ _ \ \ / // _ \| '_ \ / _` |/ _ \
#  \  /\/\/\  |  __/| |  | (_) \ V /|  __/| | | | (_| | (_) |
#   \/\ \/\ \ |_|   |_|   \___/ \_/  \___||_| |_|\__, |\___/
#      \/\ \                                     |___/
#         \ \
#
# 20:16:01.230 INFO [SETUP] We'd love to hear from you! hello@provengo.tech or https://provengo.tech/feedback/
# 20:16:01.301 INFO [SETUP] Project folder: c:\temp\ProvengoDemo\SheepWolfCabbage

# %%
# %%writefile SheepWolfCabbage/spec/js/hello-world.js
#
# // Behavior for the sheep: The farmer can move the sheep between the left and right sides of the river.
# bthread("Sheep", function () {
#     while (true) {
#         // Request to move the sheep from the left to the right side
#         request(bp.Event("RowTheBoat", { with: "Sheep", from: "L", to: "R" }));
#         // Request to move the sheep from the right to the left side
#         request(bp.Event("RowTheBoat", { with: "Sheep", from: "R", to: "L" }));
#     }
# });
#
# // Behavior for the cabbage: The farmer can move the cabbage between the left and right sides of the river.
# bthread("Cabbage", function () {
#     while (true) {
#         // Request to move the cabbage from the left to the right side
#         request(bp.Event("RowTheBoat", { with: "Cabbage", from: "L", to: "R" }));
#         // Request to move the cabbage from the right to the left side
#         request(bp.Event("RowTheBoat", { with: "Cabbage", from: "R", to: "L" }));
#     }
# });
#
# // Behavior for the wolf: The farmer can move the wolf between the left and right sides of the river.
# bthread("Wolf", function () {
#     while (true) {
#         // Request to move the wolf from the left to the right side
#         request(bp.Event("RowTheBoat", { with: "Wolf", from: "L", to: "R" }));
#         // Request to move the wolf from the right to the left side
#         request(bp.Event("RowTheBoat", { with: "Wolf", from: "R", to: "L" }));
#     }
# });
#
# // Behavior for the farmer: The farmer can move alone between the left and right sides of the river.
# bthread("Farmer", function () {
#     while (true) {
#         // Request to move alone from the left to the right side
#         // Wait for any event moving from left to right and block events moving in the opposite direction
#         sync({
#             request: bp.Event("RowTheBoat", { with: "No one", from: "L", to: "R" }),
#             waitFor: Any({ from: "L", to: "R" }),
#             block: Any({ from: "R", to: "L" })
#         });
#
#         // Request to move alone from the right to the left side
#         // Wait for any event moving from right to left and block events moving in the opposite direction
#         sync({
#             request: bp.Event("RowTheBoat", { with: "No one", from: "R", to: "L" }),
#             waitFor: Any({ from: "R", to: "L" }),
#             block: Any({ from: "L", to: "R" })
#         });
#     }
# });
#
# // Safety constraint: Prevent the wolf and sheep from being left alone on the same side.
# bthread("WolfSheepSafety", function () {
#     const WolfSheepEvents = Any({ with: "Wolf" }).or(Any({ with: "Sheep" })); // Events involving the wolf or sheep
#
#     while (true) {
#         // Ensure the wolf and sheep are not left alone by blocking invalid moves
#         sync({ waitFor: WolfSheepEvents, block: WolfSheepEvents.negate() });
#         // Wait for the farmer to move the wolf or sheep to the other side
#         waitFor(WolfSheepEvents);
#     }
# });
#
# // Safety constraint: Prevent the sheep and cabbage from being left alone on the same side.
# bthread("SheepCabbageSafety", function () {
#     const SheepCabbageEvents = Any({ with: "Sheep" }).or(Any({ with: "Cabbage" })); // Events involving the sheep or cabbage
#
#     while (true) {
#         // Ensure the sheep and cabbage are not left alone by blocking invalid moves
#         sync({ waitFor: SheepCabbageEvents, block: SheepCabbageEvents.negate() });
#         // Wait for the farmer to move the sheep or cabbage to the other side
#         waitFor(SheepCabbageEvents);
#     }
# });
#
# // Goal specification: Track the state of all entities and ensure the goal conditions are met.
# bthread("Goal Specification", function () {
#     state = { Sheep: "L", Wolf: "L", Cabbage: "L" }; // Initial state: all entities are on the left side
#
#     while (true) {
#         // Wait for any event and update the state based on the event
#         let e = waitFor(EventSets.all);
#         state[e.data.with] = e.data.to;
#
#         // Log the current state for debugging purposes
#         bp.log.info("Current state: " + JSON.stringify(state));
#
#         // Assert that the wolf, sheep, and cabbage are not all on the right side simultaneously
#         bp.ASSERT(
#             state["Wolf"] != "R" || state["Sheep"] != "R" || state["Cabbage"] != "R",
#             "The wolf, sheep and cabbage are not all on the right side of the river"
#         );
#     }
# });
# Out:
# Overwriting SheepWolfCabbage/spec/js/hello-world.js

# %%
# !provengo run SheepWolfCabbage
# Out:
#         / /
#      /\/ /   ____
#   /\/ /\/ / |  _ \ _ __  _____   __ ___  _ __   __ _  ___
#  /  \/\/\/  | |_) | '__|/ _ \ \ / // _ \| '_ \ / _` |/ _ \
#  \  /\/\/\  |  __/| |  | (_) \ V /|  __/| | | | (_| | (_) |
#   \/\ \/\ \ |_|   |_|   \___/ \_/  \___||_| |_|\__, |\___/
#      \/\ \                                     |___/
#         \ \
#
# 21:59:41.060 INFO [SETUP] We'd love to hear from you! hello@provengo.tech or https://provengo.tech/feedback/
# 21:59:41.062 INFO [SETUP] Project path: c:\temp\ProvengoDemo\SheepWolfCabbage
# 21:59:41.070 INFO [RUN] Preparing to run
# 21:59:41.399 INFO [RUN>random] B-program started
# 21:59:41.433 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"L", to:"R"}]
# 21:59:41.449 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L"}
# 21:59:41.455 INFO [RUN>random] Selected: [RowTheBoat {with:"No one", from:"R", to:"L"}]
# 21:59:41.463 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"L"}
# 21:59:41.468 INFO [RUN>random] Selected: [RowTheBoat {with:"Cabbage", from:"L", to:"R"}]
# 21:59:41.474 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"R","No one":"L"}
# 21:59:41.477 INFO [RUN>random] Selected: [RowTheBoat {with:"Cabbage", from:"R", to:"L"}]
# 21:59:41.482 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"L"}
# 21:59:41.484 INFO [RUN>random] Selected: [RowTheBoat {with:"Wolf", from:"L", to:"R"}]
# 21:59:41.490 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"R","Cabbage":"L","No one":"L"}
# 21:59:41.492 INFO [RUN>random] Selected: [RowTheBoat {with:"Wolf", from:"R", to:"L"}]
# 21:59:41.497 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"L"}
# 21:59:41.498 INFO [RUN>random] Selected: [RowTheBoat {with:"No one", from:"L", to:"R"}]
# 21:59:41.503 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"R"}
# 21:59:41.505 INFO [RUN>random] Selected: [RowTheBoat {with:"No one", from:"R", to:"L"}]
# 21:59:41.510 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"L"}
# 21:59:41.511 INFO [RUN>random] Selected: [RowTheBoat {with:"No one", from:"L", to:"R"}]
# 21:59:41.518 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"R"}
# 21:59:41.519 INFO [RUN>random] Selected: [RowTheBoat {with:"No one", from:"R", to:"L"}]
# 21:59:41.525 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"L"}
# 21:59:41.526 INFO [RUN>random] Selected: [RowTheBoat {with:"Wolf", from:"L", to:"R"}]
# 21:59:41.532 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"R","Cabbage":"L","No one":"L"}
# 21:59:41.534 INFO [RUN>random] Selected: [RowTheBoat {with:"Wolf", from:"R", to:"L"}]
# 21:59:41.539 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"L"}
# 21:59:41.540 INFO [RUN>random] Selected: [RowTheBoat {with:"Wolf", from:"L", to:"R"}]
# 21:59:41.545 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"R","Cabbage":"L","No one":"L"}
# 21:59:41.547 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"R", to:"L"}]
# 21:59:41.553 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"R","Cabbage":"L","No one":"L"}
# 21:59:41.554 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"L", to:"R"}]
# 21:59:41.559 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"R","Cabbage":"L","No one":"L"}
# 21:59:41.561 INFO [RUN>random] Selected: [RowTheBoat {with:"Wolf", from:"R", to:"L"}]
# 21:59:41.566 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"L"}
# 21:59:41.567 INFO [RUN>random] Selected: [RowTheBoat {with:"No one", from:"L", to:"R"}]
# 21:59:41.572 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"R"}
# 21:59:41.573 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"R", to:"L"}]
# 21:59:41.579 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"L","Cabbage":"L","No one":"R"}
# 21:59:41.580 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"L", to:"R"}]
# 21:59:41.586 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"R"}
# 21:59:41.587 INFO [RUN>random] Selected: [RowTheBoat {with:"No one", from:"R", to:"L"}]
# 21:59:41.591 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"L"}
# 21:59:41.592 INFO [RUN>random] Selected: [RowTheBoat {with:"Wolf", from:"L", to:"R"}]
# 21:59:41.599 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"R","Cabbage":"L","No one":"L"}
# 21:59:41.600 INFO [RUN>random] Selected: [RowTheBoat {with:"Wolf", from:"R", to:"L"}]
# 21:59:41.605 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"L"}
# 21:59:41.606 INFO [RUN>random] Selected: [RowTheBoat {with:"No one", from:"L", to:"R"}]
# 21:59:41.612 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"R"}
# 21:59:41.612 INFO [RUN>random] Selected: [RowTheBoat {with:"No one", from:"R", to:"L"}]
# 21:59:41.618 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"L"}
# 21:59:41.619 INFO [RUN>random] Selected: [RowTheBoat {with:"Cabbage", from:"L", to:"R"}]
# 21:59:41.624 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"R","No one":"L"}
# 21:59:41.625 INFO [RUN>random] Selected: [RowTheBoat {with:"Cabbage", from:"R", to:"L"}]
# 21:59:41.631 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"L"}
# 21:59:41.631 INFO [RUN>random] Selected: [RowTheBoat {with:"No one", from:"L", to:"R"}]
# 21:59:41.638 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"R"}
# 21:59:41.639 INFO [RUN>random] Selected: [RowTheBoat {with:"No one", from:"R", to:"L"}]
# 21:59:41.644 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"L"}
# 21:59:41.645 INFO [RUN>random] Selected: [RowTheBoat {with:"No one", from:"L", to:"R"}]
# 21:59:41.651 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"R"}
# 21:59:41.652 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"R", to:"L"}]
# 21:59:41.658 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"L","Cabbage":"L","No one":"R"}
# 21:59:41.659 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"L", to:"R"}]
# 21:59:41.664 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"R"}
# 21:59:41.666 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"R", to:"L"}]
# 21:59:41.671 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"L","Cabbage":"L","No one":"R"}
# 21:59:41.671 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"L", to:"R"}]
# 21:59:41.677 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"R"}
# 21:59:41.678 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"R", to:"L"}]
# 21:59:41.684 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"L","Cabbage":"L","No one":"R"}
# 21:59:41.685 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"L", to:"R"}]
# 21:59:41.692 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"R"}
# 21:59:41.692 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"R", to:"L"}]
# 21:59:41.699 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"L","Cabbage":"L","No one":"R"}
# 21:59:41.700 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"L", to:"R"}]
# 21:59:41.706 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"R"}
# 21:59:41.707 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"R", to:"L"}]
# 21:59:41.713 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"L","Cabbage":"L","No one":"R"}
# 21:59:41.713 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"L", to:"R"}]
# 21:59:41.720 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"R"}
# 21:59:41.720 INFO [RUN>random] Selected: [RowTheBoat {with:"No one", from:"R", to:"L"}]
# 21:59:41.726 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"L"}
# 21:59:41.726 INFO [RUN>random] Selected: [RowTheBoat {with:"No one", from:"L", to:"R"}]
# 21:59:41.732 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"R"}
# 21:59:41.733 INFO [RUN>random] Selected: [RowTheBoat {with:"No one", from:"R", to:"L"}]
# 21:59:41.739 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"L"}
# 21:59:41.740 INFO [RUN>random] Selected: [RowTheBoat {with:"Wolf", from:"L", to:"R"}]
# 21:59:41.744 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"R","Cabbage":"L","No one":"L"}
# 21:59:41.745 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"R", to:"L"}]
# 21:59:41.752 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"R","Cabbage":"L","No one":"L"}
# 21:59:41.752 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"L", to:"R"}]
# 21:59:41.758 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"R","Cabbage":"L","No one":"L"}
# 21:59:41.759 INFO [RUN>random] Selected: [RowTheBoat {with:"Wolf", from:"R", to:"L"}]
# 21:59:41.765 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"L"}
# 21:59:41.765 INFO [RUN>random] Selected: [RowTheBoat {with:"No one", from:"L", to:"R"}]
# 21:59:41.771 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"R"}
# 21:59:41.771 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"R", to:"L"}]
# 21:59:41.777 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"L","Cabbage":"L","No one":"R"}
# 21:59:41.778 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"L", to:"R"}]
# 21:59:41.783 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"R"}
# 21:59:41.783 INFO [RUN>random] Selected: [RowTheBoat {with:"No one", from:"R", to:"L"}]
# 21:59:41.789 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"L"}
# 21:59:41.790 INFO [RUN>random] Selected: [RowTheBoat {with:"Wolf", from:"L", to:"R"}]
# 21:59:41.795 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"R","Cabbage":"L","No one":"L"}
# 21:59:41.796 INFO [RUN>random] Selected: [RowTheBoat {with:"Wolf", from:"R", to:"L"}]
# 21:59:41.801 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"L"}
# 21:59:41.802 INFO [RUN>random] Selected: [RowTheBoat {with:"No one", from:"L", to:"R"}]
# 21:59:41.808 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"R"}
# 21:59:41.808 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"R", to:"L"}]
# 21:59:41.813 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"L","Cabbage":"L","No one":"R"}
# 21:59:41.814 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"L", to:"R"}]
# 21:59:41.819 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"R"}
# 21:59:41.820 INFO [RUN>random] Selected: [RowTheBoat {with:"No one", from:"R", to:"L"}]
# 21:59:41.826 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"L"}
# 21:59:41.827 INFO [RUN>random] Selected: [RowTheBoat {with:"No one", from:"L", to:"R"}]
# 21:59:41.831 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"R"}
# 21:59:41.832 INFO [RUN>random] Selected: [RowTheBoat {with:"No one", from:"R", to:"L"}]
# 21:59:41.837 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"L"}
# 21:59:41.838 INFO [RUN>random] Selected: [RowTheBoat {with:"Wolf", from:"L", to:"R"}]
# 21:59:41.843 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"R","Cabbage":"L","No one":"L"}
# 21:59:41.843 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"R", to:"L"}]
# 21:59:41.849 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"R","Cabbage":"L","No one":"L"}
# 21:59:41.850 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"L", to:"R"}]
# 21:59:41.855 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"R","Cabbage":"L","No one":"L"}
# 21:59:41.856 INFO [RUN>random] Selected: [RowTheBoat {with:"Wolf", from:"R", to:"L"}]
# 21:59:41.862 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"L"}
# 21:59:41.863 INFO [RUN>random] Selected: [RowTheBoat {with:"Cabbage", from:"L", to:"R"}]
# 21:59:41.869 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"R","No one":"L"}
# 21:59:41.870 INFO [RUN>random] Selected: [RowTheBoat {with:"Cabbage", from:"R", to:"L"}]
# 21:59:41.875 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"L"}
# 21:59:41.876 INFO [RUN>random] Selected: [RowTheBoat {with:"No one", from:"L", to:"R"}]
# 21:59:41.882 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"R"}
# 21:59:41.883 INFO [RUN>random] Selected: [RowTheBoat {with:"No one", from:"R", to:"L"}]
# 21:59:41.888 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"L"}
# 21:59:41.889 INFO [RUN>random] Selected: [RowTheBoat {with:"Cabbage", from:"L", to:"R"}]
# 21:59:41.894 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"R","No one":"L"}
# 21:59:41.895 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"R", to:"L"}]
# 21:59:41.900 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"L","Cabbage":"R","No one":"L"}
# 21:59:41.901 INFO [RUN>random] Selected: [RowTheBoat {with:"Wolf", from:"L", to:"R"}]
# 21:59:41.906 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"R","Cabbage":"R","No one":"L"}
# 21:59:41.907 INFO [RUN>random] Selected: [RowTheBoat {with:"Cabbage", from:"R", to:"L"}]
# 21:59:41.912 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"R","Cabbage":"L","No one":"L"}
# 21:59:41.913 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"L", to:"R"}]
# 21:59:41.918 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"R","Cabbage":"L","No one":"L"}
# 21:59:41.919 INFO [RUN>random] Selected: [RowTheBoat {with:"Wolf", from:"R", to:"L"}]
# 21:59:41.924 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"L"}
# 21:59:41.925 INFO [RUN>random] Selected: [RowTheBoat {with:"No one", from:"L", to:"R"}]
# 21:59:41.931 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"R"}
# 21:59:41.931 INFO [RUN>random] Selected: [RowTheBoat {with:"No one", from:"R", to:"L"}]
# 21:59:41.937 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"L"}
# 21:59:41.938 INFO [RUN>random] Selected: [RowTheBoat {with:"Cabbage", from:"L", to:"R"}]
# 21:59:41.942 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"R","No one":"L"}
# 21:59:41.943 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"R", to:"L"}]
# 21:59:41.948 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"L","Cabbage":"R","No one":"L"}
# 21:59:41.949 INFO [RUN>random] Selected: [RowTheBoat {with:"Wolf", from:"L", to:"R"}]
# 21:59:41.955 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"R","Cabbage":"R","No one":"L"}
# 21:59:41.955 INFO [RUN>random] Selected: [RowTheBoat {with:"Cabbage", from:"R", to:"L"}]
# 21:59:41.960 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"R","Cabbage":"L","No one":"L"}
# 21:59:41.961 INFO [RUN>random] Selected: [RowTheBoat {with:"Cabbage", from:"L", to:"R"}]
# 21:59:41.967 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"R","Cabbage":"R","No one":"L"}
# 21:59:41.968 INFO [RUN>random] Selected: [RowTheBoat {with:"Wolf", from:"R", to:"L"}]
# 21:59:41.974 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"L","Cabbage":"R","No one":"L"}
# 21:59:41.975 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"L", to:"R"}]
# 21:59:41.982 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"R","No one":"L"}
# 21:59:41.982 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"R", to:"L"}]
# 21:59:41.989 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"L","Cabbage":"R","No one":"L"}
# 21:59:41.990 INFO [RUN>random] Selected: [RowTheBoat {with:"Wolf", from:"L", to:"R"}]
# 21:59:41.996 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"R","Cabbage":"R","No one":"L"}
# 21:59:41.996 INFO [RUN>random] Selected: [RowTheBoat {with:"Wolf", from:"R", to:"L"}]
# 21:59:42.001 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"L","Cabbage":"R","No one":"L"}
# 21:59:42.002 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"L", to:"R"}]
# 21:59:42.008 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"R","No one":"L"}
# 21:59:42.009 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"R", to:"L"}]
# 21:59:42.014 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"L","Cabbage":"R","No one":"L"}
# 21:59:42.016 INFO [RUN>random] Selected: [RowTheBoat {with:"Wolf", from:"L", to:"R"}]
# 21:59:42.021 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"R","Cabbage":"R","No one":"L"}
# 21:59:42.022 INFO [RUN>random] Selected: [RowTheBoat {with:"Cabbage", from:"R", to:"L"}]
# 21:59:42.028 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"R","Cabbage":"L","No one":"L"}
# 21:59:42.029 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"L", to:"R"}]
# 21:59:42.034 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"R","Cabbage":"L","No one":"L"}
# 21:59:42.035 INFO [RUN>random] Selected: [RowTheBoat {with:"Wolf", from:"R", to:"L"}]
# 21:59:42.042 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"L"}
# 21:59:42.042 INFO [RUN>random] Selected: [RowTheBoat {with:"No one", from:"L", to:"R"}]
# 21:59:42.048 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"R"}
# 21:59:42.048 INFO [RUN>random] Selected: [RowTheBoat {with:"No one", from:"R", to:"L"}]
# 21:59:42.053 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"L"}
# 21:59:42.054 INFO [RUN>random] Selected: [RowTheBoat {with:"Wolf", from:"L", to:"R"}]
# 21:59:42.059 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"R","Cabbage":"L","No one":"L"}
# 21:59:42.060 INFO [RUN>random] Selected: [RowTheBoat {with:"Wolf", from:"R", to:"L"}]
# 21:59:42.065 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"L"}
# 21:59:42.065 INFO [RUN>random] Selected: [RowTheBoat {with:"Wolf", from:"L", to:"R"}]
# 21:59:42.070 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"R","Cabbage":"L","No one":"L"}
# 21:59:42.071 INFO [RUN>random] Selected: [RowTheBoat {with:"Wolf", from:"R", to:"L"}]
# 21:59:42.075 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"L"}
# 21:59:42.076 INFO [RUN>random] Selected: [RowTheBoat {with:"Wolf", from:"L", to:"R"}]
# 21:59:42.080 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"R","Cabbage":"L","No one":"L"}
# 21:59:42.081 INFO [RUN>random] Selected: [RowTheBoat {with:"Wolf", from:"R", to:"L"}]
# 21:59:42.086 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"L"}
# 21:59:42.086 INFO [RUN>random] Selected: [RowTheBoat {with:"Wolf", from:"L", to:"R"}]
# 21:59:42.091 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"R","Cabbage":"L","No one":"L"}
# 21:59:42.091 INFO [RUN>random] Selected: [RowTheBoat {with:"Wolf", from:"R", to:"L"}]
# 21:59:42.098 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"L"}
# 21:59:42.099 INFO [RUN>random] Selected: [RowTheBoat {with:"Wolf", from:"L", to:"R"}]
# 21:59:42.104 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"R","Cabbage":"L","No one":"L"}
# 21:59:42.105 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"R", to:"L"}]
# 21:59:42.110 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"R","Cabbage":"L","No one":"L"}
# 21:59:42.111 INFO [RUN>random] Selected: [RowTheBoat {with:"Cabbage", from:"L", to:"R"}]
# 21:59:42.116 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"R","Cabbage":"R","No one":"L"}
# 21:59:42.117 INFO [RUN>random] Selected: [RowTheBoat {with:"No one", from:"R", to:"L"}]
# 21:59:42.122 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"R","Cabbage":"R","No one":"L"}
# 21:59:42.122 INFO [RUN>random] Selected: [RowTheBoat {with:"No one", from:"L", to:"R"}]
# 21:59:42.127 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"R","Cabbage":"R","No one":"R"}
# 21:59:42.128 INFO [RUN>random] Selected: [RowTheBoat {with:"No one", from:"R", to:"L"}]
# 21:59:42.133 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"R","Cabbage":"R","No one":"L"}
# 21:59:42.133 INFO [RUN>random] Selected: [RowTheBoat {with:"No one", from:"L", to:"R"}]
# 21:59:42.139 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"R","Cabbage":"R","No one":"R"}
# 21:59:42.139 INFO [RUN>random] Selected: [RowTheBoat {with:"Cabbage", from:"R", to:"L"}]
# 21:59:42.144 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"R","Cabbage":"L","No one":"R"}
# 21:59:42.144 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"L", to:"R"}]
# 21:59:42.149 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"R","Cabbage":"L","No one":"R"}
# 21:59:42.150 INFO [RUN>random] Selected: [RowTheBoat {with:"Wolf", from:"R", to:"L"}]
# 21:59:42.155 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"R"}
# 21:59:42.156 INFO [RUN>random] Selected: [RowTheBoat {with:"No one", from:"L", to:"R"}]
# 21:59:42.160 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"R"}
# 21:59:42.161 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"R", to:"L"}]
# 21:59:42.166 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"L","Cabbage":"L","No one":"R"}
# 21:59:42.167 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"L", to:"R"}]
# 21:59:42.172 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"R"}
# 21:59:42.173 INFO [RUN>random] Selected: [RowTheBoat {with:"No one", from:"R", to:"L"}]
# 21:59:42.179 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"L"}
# 21:59:42.179 INFO [RUN>random] Selected: [RowTheBoat {with:"Wolf", from:"L", to:"R"}]
# 21:59:42.184 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"R","Cabbage":"L","No one":"L"}
# 21:59:42.185 INFO [RUN>random] Selected: [RowTheBoat {with:"Wolf", from:"R", to:"L"}]
# 21:59:42.191 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"L"}
# 21:59:42.191 INFO [RUN>random] Selected: [RowTheBoat {with:"Cabbage", from:"L", to:"R"}]
# 21:59:42.196 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"R","No one":"L"}
# 21:59:42.196 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"R", to:"L"}]
# 21:59:42.202 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"L","Cabbage":"R","No one":"L"}
# 21:59:42.203 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"L", to:"R"}]
# 21:59:42.208 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"R","No one":"L"}
# 21:59:42.209 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"R", to:"L"}]
# 21:59:42.213 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"L","Cabbage":"R","No one":"L"}
# 21:59:42.214 INFO [RUN>random] Selected: [RowTheBoat {with:"Wolf", from:"L", to:"R"}]
# 21:59:42.220 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"R","Cabbage":"R","No one":"L"}
# 21:59:42.220 INFO [RUN>random] Selected: [RowTheBoat {with:"Cabbage", from:"R", to:"L"}]
# 21:59:42.225 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"R","Cabbage":"L","No one":"L"}
# 21:59:42.226 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"L", to:"R"}]
# 21:59:42.231 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"R","Cabbage":"L","No one":"L"}
# 21:59:42.231 INFO [RUN>random] Selected: [RowTheBoat {with:"Wolf", from:"R", to:"L"}]
# 21:59:42.236 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"L","No one":"L"}
# 21:59:42.236 INFO [RUN>random] Selected: [RowTheBoat {with:"Cabbage", from:"L", to:"R"}]
# 21:59:42.241 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"L","Cabbage":"R","No one":"L"}
# 21:59:42.242 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"R", to:"L"}]
# 21:59:42.247 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"L","Cabbage":"R","No one":"L"}
# 21:59:42.248 INFO [RUN>random] Selected: [RowTheBoat {with:"Wolf", from:"L", to:"R"}]
# 21:59:42.254 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"R","Cabbage":"R","No one":"L"}
# 21:59:42.255 INFO [RUN>random] Selected: [RowTheBoat {with:"Cabbage", from:"R", to:"L"}]
# 21:59:42.261 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"R","Cabbage":"L","No one":"L"}
# 21:59:42.262 INFO [RUN>random] Selected: [RowTheBoat {with:"Cabbage", from:"L", to:"R"}]
# 21:59:42.267 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"R","Cabbage":"R","No one":"L"}
# 21:59:42.268 INFO [RUN>random] Selected: [RowTheBoat {with:"Cabbage", from:"R", to:"L"}]
# 21:59:42.272 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"R","Cabbage":"L","No one":"L"}
# 21:59:42.273 INFO [RUN>random] Selected: [RowTheBoat {with:"Cabbage", from:"L", to:"R"}]
# 21:59:42.278 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"R","Cabbage":"R","No one":"L"}
# 21:59:42.279 INFO [RUN>random] Selected: [RowTheBoat {with:"Wolf", from:"R", to:"L"}]
# 21:59:42.284 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"L","Cabbage":"R","No one":"L"}
# 21:59:42.285 INFO [RUN>random] Selected: [RowTheBoat {with:"Wolf", from:"L", to:"R"}]
# 21:59:42.290 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"R","Cabbage":"R","No one":"L"}
# 21:59:42.290 INFO [RUN>random] Selected: [RowTheBoat {with:"No one", from:"R", to:"L"}]
# 21:59:42.296 INFO [RUN>random] Current state: {"Sheep":"L","Wolf":"R","Cabbage":"R","No one":"L"}
# 21:59:42.296 INFO [RUN>random] Selected: [RowTheBoat {with:"Sheep", from:"L", to:"R"}]
# 21:59:42.301 INFO [RUN>random] Current state: {"Sheep":"R","Wolf":"R","Cabbage":"R","No one":"L"}
# 21:59:42.302 INFO [RUN>random] Assertion failed: The wolf, sheep and cabbage are not all on the right side of the river
# 21:59:42.319 INFO [RUN] Test Result: SUCCESS

# %%
# !provengo verify SheepWolfCabbage
# Out:
#         / /
#      /\/ /   ____
#   /\/ /\/ / |  _ \ _ __  _____   __ ___  _ __   __ _  ___
#  /  \/\/\/  | |_) | '__|/ _ \ \ / // _ \| '_ \ / _` |/ _ \
#  \  /\/\/\  |  __/| |  | (_) \ V /|  __/| | | | (_| | (_) |
#   \/\ \/\ \ |_|   |_|   \___/ \_/  \___||_| |_|\__, |\___/
#      \/\ \                                     |___/
#         \ \
#
# 21:38:03.359 INFO [VERSION] 1b75ef8/20250331-0214/master
# 21:38:03.369 ERR  [Main] Terminating because of previous errors. See logs.
# 21:38:03.375 ERR  [Main] 40 BadRequest
# usage: provengo [-h] [--verbose] [--batch-mode] [--no-color]
#                 [--config CONFIG] [-p PROFILE] [-c [CUSTOM]] [-v]
#                 {run,analyze,gen-scripts,report,sample,ensemble,gen-book,create}
#                 ...
# provengo: error: invalid choice:  'verify'  (choose  from 'run', 'analyze',
# 'gen-scripts', 'report', 'sample', 'ensemble', 'gen-book', 'create')
